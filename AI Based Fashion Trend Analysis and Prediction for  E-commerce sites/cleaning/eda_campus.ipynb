# %%
import pandas as pd
import random

# %%
df1=pd.read_json('campus.json')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 991 entries, 0 to 990
# Data columns (total 79 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0.1                         991 non-null    int64
#  1   Unnamed: 0                           991 non-null    int64
#  2   Title                                991 non-null    object
#  3   Price                                991 non-null    object
#  4   Rating                               862 non-null    float64
#  5   Reviews                              875 non-null    object
#  6   Url                                  991 non-null    object
#  7   Seller                               989 non-null    object
#  8   Type                                 553 non-null    object
#  9   Sleeve                               749 non-null    object
#  10  Fit                                  574 non-null    object
#  11  Fabric                               988 non-null    object
#  12  Sales Package                        370 non-null    object
#  13  Pack of                              672 non-null    float64
#  14  Style Code                           770 non-null    object
#  15  Neck Type                            294 non-null    object
#  16  Ideal For                            479 non-null    object
#  17  Size                                 302 non-null    object
#  18  Pattern                              961 non-null    object
#  19  Suitable For                         636 non-null    object
#  20  Brand Fit                            142 non-null    object
#  21  Sleeve Type                          151 non-null    object
#  22  Reversible                           714 non-null    object
#  23  Fabric Care                          667 non-null    object
#  24  Net Quantity                         964 non-null    object
#  25  Secondary Color                      28 non-null     object
#  26  Closure                              417 non-null    object
#  27  Collar                               204 non-null    object
#  28  Color                                687 non-null    object
#  29  Hem                                  167 non-null    object
#  30  Other Details                        348 non-null    object
#  31  Style code                           153 non-null    object
#  32  Ideal for                            145 non-null    object
#  33  Sales package                        89 non-null     object
#  34  Suitable for                         140 non-null    object
#  35  Hooded                               147 non-null    object
#  36  Fabric care                          148 non-null    object
#  37  Neck                                 174 non-null    object
#  38  Pockets                              130 non-null    object
#  39  Model Name                           11 non-null     object
#  40  Pack Of                              55 non-null     float64
#  41  Pocket Type                          12 non-null     object
#  42  Faded                                55 non-null     object
#  43  Rise                                 55 non-null     object
#  44  Distressed                           55 non-null     object
#  45  Fly                                  24 non-null     object
#  46  Character                            0 non-null      float64
#  47  Knit type                            3 non-null      object
#  48  Other details                        52 non-null     object
#  49  Length                               12 non-null     object
#  50  Occasion                             90 non-null     object
#  51  Pck of                               8 non-null      float64
#  52  Coat Type                            15 non-null     object
#  53  Water Resistant                      10 non-null     object
#  54  Number of Contents in Sales Package  96 non-null     object
#  55  Unnamed: 54                          66 non-null     object
#  56  Sleeve Length                        12 non-null     object
#  57  Secondary color                      8 non-null      object
#  58  Sleeve Style                         5 non-null      object
#  59  Stretchable                          7 non-null      object
#  60  Series                               32 non-null     object
#  61  Rise in inch                         1 non-null      object
#  62  Thigh in inch                        1 non-null      object
#  63  Waist in inch                        1 non-null      object
#  64  Other Dimensions                     4 non-null      object
#  65  Belt Included                        4 non-null      object
#  66  Brand                                8 non-null      object
#  67  Brand color                          4 non-null      object
#  68  Label size                           4 non-null      object
#  69  Primary product type                 4 non-null      object
#  70  Secondary product type               4 non-null      object
#  71  Primary Color                        8 non-null      object
#  72  Suitabl for                          4 non-null      object
#  73  Fabric details                       4 non-null      object
#  74  Number of Track Pants                4 non-null      float64
#  75  Brand Color                          4 non-null      object
#  76  Group ID                             4 non-null      object
#  77  Fabric Details                       4 non-null      object
#  78  total                                991 non-null    object
# dtypes: float64(6), int64(2), object(71)
# memory usage: 619.4+ KB

# %%
df=df1[['Title','Price','Rating','Reviews','Color','Seller','Type','Fabric','Ideal for','Pattern','total','Url']]

# %%
df.isnull().sum()
# Out:
# Title          0
# Price          0
# Rating       129
# Reviews      116
# Color        304
# Seller         2
# Type         438
# Fabric         3
# Ideal for    846
# Pattern       30
# total          0
# Url            0
# dtype: int64

# %%
patterns=list(set(df['Pattern']))
patterns.remove(None)
#unique_patterns = set(patterns)  # Create set outside the function for efficiency
def pattern_fill(row):
    if row['Pattern'] is None:
        for pattern in patterns:
            if pattern in row['Title']:
                return type
        # Handle cases where no match is found (return default, raise error, etc.)
    else:
        return row['Pattern']


colours=list(set(df['Color']))
colours.remove(None)

def colour_fill(row):
    if row['Color'] is None:
        for color in colours:
            if color.lower( ) in row['Title'].lower():   # Make case-insensitive
                return color
    else:
        return  row['Color']
    
    
persons=['Men','Women','Kid']
def idealfor(row):
    for x in persons:
        if x.lower( ) in row['Title'].lower():   # Make case-insensitive
            return x
        
        
def type_fill(row):
    y=row.Title
    y=y.split(' ')
    if y[-1]=='Women':
        return None
    return y[-1]


def rat_cnt(row):
    if row==0:
        return 0
    x=row.replace(',','')
    x=x.split(" ")
    return x[0]


def rev_cnt(row):
    if row==0:
        return 0
    x=row.replace(',','')
    x=x.split(" ")
    return x[0]

# %%
df['Pattern'] = df.apply(pattern_fill, axis=1)
df['Color'] = df.apply(colour_fill, axis=1)
df['Ideal for']=df.apply(idealfor,axis=1)
df['Type']=df.apply(type_fill,axis=1)
df.Type.fillna('Coat',inplace=True)
df["Pattern"].fillna(random.choice(patterns), inplace=True)
df["Color"].fillna(random.choice(colours), inplace=True)
fabrics=list(set(df['Fabric']))
df["Fabric"].fillna(random.choice(fabrics), inplace=True)


df.Rating=df.Rating.fillna(-1)
df['Price']=df['Price'].apply(lambda x: x[1:]).str.replace(',','').astype(int)
df=df[df["Seller"]=="CAMPUS SUTRA"]

df["code"]=df.total.apply(lambda x : x[1])
df["nlp"]=df.total.apply(lambda x : x[2])
df["Stars"]=df.total.apply(lambda x : x[3])

df["1 star"]=df.Stars.apply(lambda x : str(x[0]).replace(',','')).astype(int)
df["2 stars"]=df.Stars.apply(lambda x : str(x[1]).replace(',','')).astype(int)
df["3 stars"]=df.Stars.apply(lambda x: str(x[2]).replace(',','')).astype(int)
df["4 stars"]=df.Stars.apply(lambda x: str(x[3]).replace(',','')).astype(int)
df["5 stars"]=df.Stars.apply(lambda x: str(x[4]).replace(',','')).astype(int)


df.Reviews.fillna(0, inplace=True)
df['Rating count']=df['Reviews'].apply(rat_cnt)
df['Review count']=df['Reviews'].apply(rev_cnt)
#df[df['Reviews']!=0]['Rating count']=df[df['Reviews']!=0]['Reviews'].apply(lambda x: x.replace(',','').split(' ')[0])
#df[df['Reviews']!=0]['Review count']=df[df['Reviews']!=0]['Reviews'].apply(lambda x: x.replace(',','').split(' ')[3])

df.drop("Stars",axis=1,inplace=True)
df.drop("total",axis=1,inplace=True)
# Out:
# /tmp/ipykernel_461169/1435576668.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pattern'] = df.apply(pattern_fill, axis=1)
# /tmp/ipykernel_461169/1435576668.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Color'] = df.apply(colour_fill, axis=1)
# /tmp/ipykernel_461169/1435576668.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ideal for']=df.apply(idealfor,axis=1)
# /tmp/ipykernel_461169/1435576668.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Type']=df.apply(type_fill,axis=1)
# /tmp/ipykernel_461169/1435576668.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Type.fillna('Coat',inplace=True)
# /tmp/ipykernel_461169/1435576668.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Type.fillna('Coat',inplace=True)
# /tmp/ipykernel_461169/1435576668.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Pattern"].fillna(random.choice(patterns), inplace=True)
# /tmp/ipykernel_461169/1435576668.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Pattern"].fillna(random.choice(patterns), inplace=True)
# /tmp/ipykernel_461169/1435576668.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].fillna(random.choice(colours), inplace=True)
# /tmp/ipykernel_461169/1435576668.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Color"].fillna(random.choice(colours), inplace=True)
# /tmp/ipykernel_461169/1435576668.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Fabric"].fillna(random.choice(fabrics), inplace=True)
# /tmp/ipykernel_461169/1435576668.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Fabric"].fillna(random.choice(fabrics), inplace=True)
# /tmp/ipykernel_461169/1435576668.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Rating=df.Rating.fillna(-1)
# /tmp/ipykernel_461169/1435576668.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price']=df['Price'].apply(lambda x: x[1:]).str.replace(',','').astype(int)
# /tmp/ipykernel_461169/1435576668.py:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Reviews.fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Title           0
# Price           0
# Rating          0
# Reviews         0
# Color           0
# Seller          0
# Type            0
# Fabric          0
# Ideal for       0
# Pattern         0
# Url             0
# code            0
# nlp             0
# 1 star          0
# 2 stars         0
# 3 stars         0
# 4 stars         0
# 5 stars         0
# Rating count    0
# Review count    0
# dtype: int64

# %%
df.to_json('clean/campus.json')
